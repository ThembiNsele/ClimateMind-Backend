# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
import os

os.path.exists('ESS1-9e01_11.csv')
cwd = os.getcwd()
print(cwd)
# Out:
# /Users/alexiscarras/CODE/cm backend/climatemind-backend/ml_models/political_preference/notebooks

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  'ESS Data Extraction.ipynb',
#  'pvq21 exploration-analysis.ipynb',
#  'ESS1_9e01_1.csv',
#  'ML EXPE.ipynb',
#  'readme.txt',
#  '.ipynb_checkpoints']

# %%
ess = pd.read_csv('/Users/alexiscarras/CODE/cm backend/climatemind-backend/ml_models/political_preference/datasets/ESS/ESS1-9e01_1.csv')

# %%
length = len(ess)
shape = ess.shape


print(f"Length: {length} \nShape: {shape}")
# Out:
# Length: 422985
# Shape: (422985, 35)

# %%
pd.set_option('display.max_columns', None)

ess.head(-50)
# Out:
#        cntry      cname  cedition    cproddat  cseqno       name  essround  \
# 0         AT  ESS1-9e01       1.0  10.12.2020       1  ESS1e06_6         1
# 1         AT  ESS1-9e01       1.0  10.12.2020       2  ESS1e06_6         1
# 2         AT  ESS1-9e01       1.0  10.12.2020       3  ESS1e06_6         1
# 3         AT  ESS1-9e01       1.0  10.12.2020       4  ESS1e06_6         1
# 4         AT  ESS1-9e01       1.0  10.12.2020       5  ESS1e06_6         1
# ...      ...        ...       ...         ...     ...        ...       ...
# 422930    UA  ESS1-9e01       1.0  10.12.2020  422931  ESS6e02_4         6
# 422931    UA  ESS1-9e01       1.0  10.12.2020  422932  ESS6e02_4         6
# 422932    UA  ESS1-9e01       1.0  10.12.2020  422933  ESS6e02_4         6
# 422933    UA  ESS1-9e01       1.0  10.12.2020  422934  ESS6e02_4         6
# 422934    UA  ESS1-9e01       1.0  10.12.2020  422935  ESS6e02_4         6
#
# ...

# %%
ess_9 = ess[ess["essround"]==9]

# %%
ess_9
# Out:
#        cntry      cname  cedition    cproddat  cseqno     name  essround  \
# 10723     AT  ESS1-9e01       1.0  10.12.2020   10724  ESS9e03         9
# 10724     AT  ESS1-9e01       1.0  10.12.2020   10725  ESS9e03         9
# 10725     AT  ESS1-9e01       1.0  10.12.2020   10726  ESS9e03         9
# 10726     AT  ESS1-9e01       1.0  10.12.2020   10727  ESS9e03         9
# 10727     AT  ESS1-9e01       1.0  10.12.2020   10728  ESS9e03         9
# ...      ...        ...       ...         ...     ...      ...       ...
# 408721    SK  ESS1-9e01       1.0  10.12.2020  408722  ESS9e03         9
# 408722    SK  ESS1-9e01       1.0  10.12.2020  408723  ESS9e03         9
# 408723    SK  ESS1-9e01       1.0  10.12.2020  408724  ESS9e03         9
# 408724    SK  ESS1-9e01       1.0  10.12.2020  408725  ESS9e03         9
# 408725    SK  ESS1-9e01       1.0  10.12.2020  408726  ESS9e03         9
#
#         edition   idno   dweight   pspwght   pweight  anweight  lrscale  \
# ...

# %%
ess_9.to_csv('../datasets/ess/ess_9.csv', index = False)
